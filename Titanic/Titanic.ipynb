# %%
import numpy
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from keras.models import Sequential
from keras.layers import Dense,Dropout
# Out:
# C:\Users\admin\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def readData():   
    get_data=pd.read_excel("Titanic_Data.xls")

    column=["survived","name","pclass","sex","age","sibsp","parch","fare","embarked"]

    get_data=get_data[column]
    get_data=get_data.drop(['name'],axis=1)

    age_mean=get_data['age'].mean()
    get_data['age']=get_data['age'].fillna(age_mean)

    age_mean=get_data['fare'].mean()
    get_data['fare']=get_data['fare'].fillna(age_mean)

    get_data['sex']=get_data['sex'].map({'female':0,'male':1}).astype(int)

    get_data=pd.get_dummies(data=get_data,columns=["embarked"])
    
    return get_data

# %%
#processed data
data=readData()
print(data)
# Out:
#       survived  pclass  sex        age  sibsp  parch      fare  embarked_C  \
# 0            1       1    0  29.000000      0      0  211.3375           0
# 1            1       1    1   0.916700      1      2  151.5500           0
# 2            0       1    0   2.000000      1      2  151.5500           0
# 3            0       1    1  30.000000      1      2  151.5500           0
# 4            0       1    0  25.000000      1      2  151.5500           0
# 5            1       1    1  48.000000      0      0   26.5500           0
# 6            1       1    0  63.000000      1      0   77.9583           0
# 7            0       1    1  39.000000      0      0    0.0000           0
# 8            1       1    0  53.000000      2      0   51.4792           0
# 9            0       1    1  71.000000      0      0   49.5042           1
# 10           0       1    1  47.000000      1      0  227.5250           1
# 11           1       1    0  18.000000      1      0  227.5250           1
# 12           1       1    0  24.000000      0      0   69.3000           1
# 13           1       1    0  26.000000      0      0   78.8500           0
# 14           1       1    1  80.000000      0      0   30.0000           0
# 15           0       1    1  29.881135      0      0   25.9250           0
# 16           0       1    1  24.000000      0      1  247.5208           1
# 17           1       1    0  50.000000      0      1  247.5208           1
# 18           1       1    0  32.000000      0      0   76.2917           1
# 19           0       1    1  36.000000      0      0   75.2417           1
# 20           1       1    1  37.000000      1      1   52.5542           0
# 21           1       1    0  47.000000      1      1   52.5542           0
# 22           1       1    1  26.000000      0      0   30.0000           1
# 23           1       1    0  42.000000      0      0  227.5250           1
# 24           1       1    0  29.000000      0      0  221.7792           0
# 25           0       1    1  25.000000      0      0   26.0000           1
# 26           1       1    1  25.000000      1      0   91.0792           1
# 27           1       1    0  19.000000      1      0   91.0792           1
# 28           1       1    0  35.000000      0      0  135.6333           0
# 29           1       1    1  28.000000      0      0   26.5500           0
# ...        ...     ...  ...        ...    ...    ...       ...         ...
# 1279         0       3    0  14.000000      0      0    7.8542           0
# 1280         0       3    1  22.000000      0      0    7.8958           0
# 1281         0       3    1  22.000000      0      0    9.0000           0
# 1282         0       3    1  29.881135      0      0    8.0500           0
# 1283         0       3    1  29.881135      0      0    7.5500           0
# 1284         0       3    1  29.881135      0      0    8.0500           0
# 1285         0       3    1  32.500000      0      0    9.5000           0
# 1286         1       3    0  38.000000      0      0    7.2292           1
# 1287         0       3    1  51.000000      0      0    7.7500           0
# 1288         0       3    1  18.000000      1      0    6.4958           0
# 1289         0       3    1  21.000000      1      0    6.4958           0
# 1290         1       3    0  47.000000      1      0    7.0000           0
# 1291         0       3    1  29.881135      0      0    8.7125           0
# 1292         0       3    1  29.881135      0      0    7.5500           0
# 1293         0       3    1  29.881135      0      0    8.0500           0
# 1294         0       3    1  28.500000      0      0   16.1000           0
# 1295         0       3    1  21.000000      0      0    7.2500           0
# 1296         0       3    1  27.000000      0      0    8.6625           0
# 1297         0       3    1  29.881135      0      0    7.2500           0
# 1298         0       3    1  36.000000      0      0    9.5000           0
# 1299         0       3    1  27.000000      1      0   14.4542           1
# 1300         1       3    0  15.000000      1      0   14.4542           1
# 1301         0       3    1  45.500000      0      0    7.2250           1
# 1302         0       3    1  29.881135      0      0    7.2250           1
# 1303         0       3    1  29.881135      0      0   14.4583           1
# 1304         0       3    0  14.500000      1      0   14.4542           1
# 1305         0       3    0  29.881135      1      0   14.4542           1
# 1306         0       3    1  26.500000      0      0    7.2250           1
# 1307         0       3    1  27.000000      0      0    7.2250           1
# 1308         0       3    1  29.000000      0      0    7.8750           0
#
#       embarked_Q  embarked_S
# 0              0           1
# 1              0           1
# 2              0           1
# 3              0           1
# 4              0           1
# 5              0           1
# 6              0           1
# 7              0           1
# 8              0           1
# 9              0           0
# 10             0           0
# 11             0           0
# 12             0           0
# 13             0           1
# 14             0           1
# 15             0           1
# 16             0           0
# 17             0           0
# 18             0           0
# 19             0           0
# 20             0           1
# 21             0           1
# 22             0           0
# 23             0           0
# 24             0           1
# 25             0           0
# 26             0           0
# 27             0           0
# 28             0           1
# 29             0           1
# ...          ...         ...
# 1279           0           1
# 1280           0           1
# 1281           0           1
# 1282           0           1
# 1283           0           1
# 1284           0           1
# 1285           0           1
# 1286           0           0
# 1287           0           1
# 1288           0           1
# 1289           0           1
# 1290           0           1
# 1291           0           1
# 1292           0           1
# 1293           0           1
# 1294           0           1
# 1295           0           1
# 1296           0           1
# 1297           0           1
# 1298           0           1
# 1299           0           0
# 1300           0           0
# 1301           0           0
# 1302           0           0
# 1303           0           0
# 1304           0           0
# 1305           0           0
# 1306           0           0
# 1307           0           0
# 1308           0           1
#
# [1309 rows x 10 columns]

# %%
#age-->survived
data=readData()
columns=['survived','age']
data=data[columns]
data=data[data['survived']==1]
data=data.drop(["survived"], axis=1)
plt.hist(data['age'])
plt.show()

# %%
#sex-->survived
#0-->woman
#1-->man
data=readData()
columns=['survived','sex']
data=data[columns]
data=data[data['survived']==1]
data=data.drop(["survived"], axis=1)
plt.hist(data['sex'])
plt.show()

# %%
#fare-->survived
data=readData()
columns=['survived','fare']
data=data[columns]
data=data[data['survived']==1]
data=data.drop(["survived"], axis=1)
plt.hist(data['fare'])
plt.show()

# %%
#Plot HeatMap using seaborn
data=readData()
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
#use MLP to predict survive rate

data=readData()

msk=numpy.random.rand(len(data))<0.8

data=data.values
answer=data[:,0]
features=data[:,1:]

scale=preprocessing.MinMaxScaler(feature_range=(0,1))
features=scale.fit_transform(features)


train_x=features[msk]
train_y=answer[msk]
test_x=features[~msk]
test_y=answer[~msk]


model=Sequential()
model.add(Dense(units=40,input_dim=9,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=30,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
train_history=model.fit(x=train_x,y=train_y,validation_split=0.1,epochs=30,batch_size=30,verbose=1)

def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train','validation'],loc='upper left')
    plt.show()

accuracy=model.evaluate(x=test_x,y=test_y)
print("")
print("")
print("")
print('accuracy:',accuracy[1])

show_train_history(train_history,'acc','val_acc')
show_train_history(train_history,'loss','val_loss')
# Out:
# Train on 941 samples, validate on 105 samples
# Epoch 1/30
# 941/941 [==============================] - 0s 292us/step - loss: 0.6896 - acc: 0.5855 - val_loss: 0.6690 - val_acc: 0.8095
# Epoch 2/30
# 941/941 [==============================] - 0s 33us/step - loss: 0.6590 - acc: 0.6259 - val_loss: 0.5563 - val_acc: 0.8095
# Epoch 3/30
# 941/941 [==============================] - 0s 30us/step - loss: 0.5893 - acc: 0.6971 - val_loss: 0.4657 - val_acc: 0.8000
# Epoch 4/30
# 941/941 [==============================] - 0s 35us/step - loss: 0.5276 - acc: 0.7662 - val_loss: 0.4511 - val_acc: 0.8000
# Epoch 5/30
# 941/941 [==============================] - 0s 36us/step - loss: 0.4955 - acc: 0.7790 - val_loss: 0.4373 - val_acc: 0.8000
# Epoch 6/30
# 941/941 [==============================] - 0s 35us/step - loss: 0.