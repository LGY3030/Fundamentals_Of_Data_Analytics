# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# C:\Users\admin\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# 讀取data_preprocessed.csv
data=pd.read_csv("data_preprocessed.csv")
data=data.drop(["Unnamed: 0"], axis=1)

# 將資料分為train_x,train_y,test_x,test_y
columns=list(data.columns)
columns.remove('Revenue')
train_x=data[columns]
train_y=data[['Revenue']]
test_x=train_x[-1000:]
test_y=train_y[-1000:]
train_x=train_x[:-1000]
train_y=train_y[:-1000]
test_x=test_x.reset_index()
test_y=test_y.reset_index()
test_x=test_x.drop(["index"], axis=1)
test_y=test_y.drop(["index"], axis=1)
train_x['PageValues']=train_x['PageValues']*10
test_x['PageValues']=test_x['PageValues']*10
train_x['Month']=train_x['Month']*5
test_x['Month']=test_x['Month']*5

# create the model
model=Sequential()

# add layers
model.add(Dense(units=10,input_dim=train_x.shape[1],kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# show the summary
model.summary()

# compile the model
model.compile(loss='binary_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])

# fit the model
history=model.fit(train_x,train_y,epochs=50,batch_size=32,validation_split=0.2,verbose=1)

# accuracy
accuracy=model.evaluate(test_x, test_y)[1]*100

# print result
print("")
print("")
print("Accuracy of test:")
print(accuracy)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 10)                180
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 11
# ...
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________
# Train on 9064 samples, validate on 2266 samples
# Epoch 1/50
# 9064/9064 [==============================] - 0s 46us/step - loss: 0.4299 - acc: 0.8922 - val_loss: 0.4887 - val_acc: 0.8292
# Epoch 2/50
# 9064/9064 [==============================] - 0s 21us/step - loss: 0.3580 - acc: 0.8972 - val_loss: 0.4067 - val_acc: 0.8389
# Epoch 3/50
# 9064/9064 [==============================] - 0s 22us/step - loss: 0.3128 - acc: 0.8987 - val_loss: 0.7519 - val_acc: 0.8327
# Epoch 4/50
# ...

# %%
# 讀取data_preprocessed.csv
data=pd.read_csv("data_preprocessed.csv")
data=data.drop(["Unnamed: 0"], axis=1)

# 將資料分為train_x,train_y,test_x,test_y
columns=list(data.columns)
columns.remove('Revenue')
train_x=data[columns]
train_y=data[['Revenue']]
test_x=train_x[-1000:]
test_y=train_y[-1000:]
train_x=train_x[:-1000]
train_y=train_y[:-1000]
test_x=test_x.reset_index()
test_y=test_y.reset_index()
test_x=test_x.drop(["index"], axis=1)
test_y=test_y.drop(["index"], axis=1)
train_x['PageValues']=train_x['PageValues']*10
test_x['PageValues']=test_x['PageValues']*10
train_x['Month']=train_x['Month']*5
test_x['Month']=test_x['Month']*5

# create the model
model=Sequential()

# add layers
model.add(Dense(units=10,input_dim=train_x.shape[1],kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=5,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# show the summary
model.summary()

# compile the model
model.compile(loss='binary_crossentropy',optimizer=Adam(lr=0.0005),metrics=['accuracy'])

# fit the model
history=model.fit(train_x,train_y,epochs=50,batch_size=32,validation_split=0.2,verbose=1)

# accuracy
accuracy=model.evaluate(test_x, test_y)[1]*100

# print result
print("")
print("")
print("Accuracy of test:")
print(accuracy)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 10)                180
# _________________________________________________________________
# dense_13 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 6
# ...
# Total params: 241
# Trainable params: 241
# Non-trainable params: 0
# _________________________________________________________________
# Train on 9064 samples, validate on 2266 samples
# Epoch 1/50
# 9064/9064 [==============================] - 1s 59us/step - loss: 0.5119 - acc: 0.8784 - val_loss: 0.4673 - val_acc: 0.8495
# Epoch 2/50
# 9064/9064 [==============================] - 0s 28us/step - loss: 0.3191 - acc: 0.9062 - val_loss: 0.4907 - val_acc: 0.8508
# Epoch 3/50
# ...
